# %% [markdown]
# # Traffic assignment SO congestion + CO2 (min)
#
# $$
# P_k =
# \frac{\exp(-\mu \beta_{\text{time}} C_k)}
# {\sum_{j \in \mathcal{K}_{od}} \exp(-\mu \beta_{\text{time}} C_j)}
# $$
#
#
# k_paths=5
# mu=100.0
# beta_time=1.0
# max_iter=500
# tol=1e-6

# %%
import math
import numpy as np
import pandas as pd
import networkx as nx

# ============================
# 0) CO2 parameters (Paper: Barth & Boriboonsomsin, Real-World)  [Eq(1) + Table 1]
# ============================
# Paper (Real-World):
#   ln(y) = b0 + b1*x + b2*x^2 + b3*x^3 + b4*x^4
#   y: CO2 [g/mi], x: speed [mph]
#
# We convert to:
#   ln(EF) = A0 + A1*v + A2*v^2 + A3*v^3 + A4*v^4
#   EF: CO2 [g/km], v: speed [km/h]
#
# Conversion:
#   x = v / k,  y = k * EF,  k = 1.609344 (km per mile)
#   ln(EF) = ln(y) - ln(k)
# => A0 = b0 - ln(k)
#    A1 = b1 / k
#    A2 = b2 / k^2
#    A3 = b3 / k^3
#    A4 = b4 / k^4
#
# Real-World coefficients from Table 1 (paper)  :contentReference[oaicite:1]{index=1}
B0 = 7.613534994965560
B1 = -0.138565467462594
B2 = 0.003915102063854
B3 = -0.000049451361017
B4 = 0.000000238630156

K_KM_PER_MILE = 1.609344

def convert_b_to_A(b0, b1, b2, b3, b4, k=K_KM_PER_MILE):
    A0 = b0 - math.log(k)
    A1 = b1 / k
    A2 = b2 / (k**2)
    A3 = b3 / (k**3)
    A4 = b4 / (k**4)
    return A0, A1, A2, A3, A4

A0, A1, A2, A3, A4 = convert_b_to_A(B0, B1, B2, B3, B4)

p_CO2 = 15.0          # yen / kg-CO2
VOT = 43.74           # yen / min
lambda_CO2 = p_CO2 / VOT   # min / kg-CO2

V_MIN = 5.0           # km/h (safety)
V_MAX = 130.0         # km/h


# ----------------------------
# 1) Read & normalize inputs
# ----------------------------
def read_net_csv(path: str) -> pd.DataFrame:
    df = pd.read_csv(path)
    df.columns = df.columns.str.strip()

    if ";" in df.columns:
        df = df.drop(columns=[";"])

    required = ["A", "B", "capacity", "t0_min", "bpr_B", "bpr_power", "length_km"]
    missing = [c for c in required if c not in df.columns]
    if missing:
        raise ValueError(f"net.csv missing columns: {missing}. got: {df.columns.tolist()}")

    out = pd.DataFrame()
    out["u"] = df["A"].astype(int)
    out["v"] = df["B"].astype(int)
    out["cap"] = df["capacity"].astype(float)
    out["t0"] = df["t0_min"].astype(float)
    out["alpha"] = df["bpr_B"].astype(float)
    out["beta"] = df["bpr_power"].astype(float)
    out["length"] = df["length_km"].astype(float)

    return out


def read_od_csv(path: str) -> pd.DataFrame:
    od = pd.read_csv(path)
    od.columns = od.columns.str.strip()

    col_map = {}
    for c in od.columns:
        lc = c.lower()
        if lc in ["o", "origin"]:
            col_map[c] = "origin"
        elif lc in ["d", "dest", "destination"]:
            col_map[c] = "destination"
        elif lc in ["ton", "demand", "trips", "q"]:
            col_map[c] = "demand"
    od = od.rename(columns=col_map)

    required = ["origin", "destination", "demand"]
    missing = [c for c in required if c not in od.columns]
    if missing:
        raise ValueError(f"od.csv missing columns: {missing}. got: {od.columns.tolist()}")

    od = od[required].copy()
    od["origin"] = od["origin"].astype(int)
    od["destination"] = od["destination"].astype(int)
    od["demand"] = od["demand"].astype(float)

    od = od[(od["demand"] > 0) & (od["origin"] != od["destination"])].reset_index(drop=True)
    return od


# ----------------------------
# 2) BPR & marginal congestion
# ----------------------------
def bpr_time(t0, x, cap, alpha=0.15, beta=4.0):
    if cap <= 0:
        return float("inf")
    return t0 * (1.0 + alpha * (x / cap) ** beta)

def bpr_marginal_time(t0, x, cap, alpha=0.15, beta=4.0):
    if cap <= 0:
        return float("inf")
    return t0 * (1.0 + alpha * (1.0 + beta) * (x / cap) ** beta)


# ----------------------------
# 3) CO2-related functions (UPDATED: paper-based EF in g/km, v in km/h)
# ----------------------------
def clip_speed(v_kmh: float) -> float:
    return max(V_MIN, min(V_MAX, float(v_kmh)))

def emission_factor(v_kmh: float) -> float:
    """
    EF(v) [g/km]
    EF(v) = exp(A0 + A1*v + A2*v^2 + A3*v^3 + A4*v^4)
    """
    v = max(0.1, clip_speed(v_kmh))  # avoid v=0 for numerical stability
    ln_ef = A0 + A1*v + A2*(v**2) + A3*(v**3) + A4*(v**4)
    return float(math.exp(ln_ef))

def co2_cost_min(length_km: float, t_min: float) -> float:
    """
    CO2 cost converted into minutes (min/veh)
    """
    if t_min <= 0 or length_km <= 0:
        return 0.0

    v_kmh = clip_speed(60.0 * length_km / t_min)  # km/h
    ef = emission_factor(v_kmh)                   # g/km
    co2_kg = ef * length_km / 1000.0              # kg/veh
    return lambda_CO2 * co2_kg                    # min/veh


# ----------------------------
# 4) Logit-SUE via MSA (SO + CO2)
# ----------------------------
def run_logit_sue_so_congestion_co2(net: pd.DataFrame,
                                    od: pd.DataFrame,
                                    k_paths=10,
                                    mu=1.0,
                                    beta_time=1.0,
                                    max_iter=60,
                                    tol=1e-5):

    edges = list(zip(net["u"].tolist(), net["v"].tolist()))
    x = {e: 0.0 for e in edges}

    G = nx.DiGraph()
    for (u, v), t0 in zip(edges, net["t0"].tolist()):
        G.add_edge(u, v, weight=float(t0))

    def compute_edge_costs(x_dict):
        c = {}
        for i, (u, v) in enumerate(edges):
            row = net.iloc[i]

            # congestion SO marginal cost
            mc = bpr_marginal_time(
                row["t0"], x_dict[(u, v)],
                row["cap"], row["alpha"], row["beta"]
            )

            # CO2 cost (min) using updated EF(v)
            co2 = co2_cost_min(row["length"], mc)

            c[(u, v)] = mc + co2

        return c

    def rel_change(x_old, x_new):
        num = sum(abs(x_new[e] - x_old[e]) for e in edges)
        den = max(1.0, sum(abs(x_old[e]) for e in edges))
        return num / den

    for it in range(1, max_iter + 1):
        edge_costs = compute_edge_costs(x)

        for (u, v), cost in edge_costs.items():
            G[u][v]["weight"] = float(cost)

        x_hat = {e: 0.0 for e in edges}

        for _, r in od.iterrows():
            o, d, q = int(r["origin"]), int(r["destination"]), float(r["demand"])
            if q <= 0:
                continue

            cand_paths = nx.shortest_simple_paths(G, o, d, weight="weight")
            paths = []
            for _ in range(k_paths):
                try:
                    p = next(cand_paths)
                    paths.append(list(zip(p[:-1], p[1:])))
                except StopIteration:
                    break

            if not paths:
                continue

            utils = []
            for p in paths:
                cost_p = sum(edge_costs[e] for e in p)
                utils.append(-beta_time * cost_p)

            umax = max(utils)
            probs = np.exp(mu * (np.array(utils) - umax))
            probs = probs / probs.sum()

            for p, pk in zip(paths, probs):
                for e in p:
                    x_hat[e] += q * pk

        step = 1.0 / it
        x_new = {e: x[e] + step * (x_hat[e] - x[e]) for e in edges}

        gap = rel_change(x, x_new)
        x = x_new
        print(f"[SO+CO2] Iter {it:02d} | step={step:.4f} | rel_change={gap:.6e}")

        if gap < tol:
            break

    out = net.copy()
    out["flow"] = [x[(u, v)] for (u, v) in edges]

    out["time"] = [
        bpr_time(out.loc[i, "t0"], out.loc[i, "flow"],
                 out.loc[i, "cap"], out.loc[i, "alpha"], out.loc[i, "beta"])
        for i in range(len(out))
    ]

    out["mc_time"] = [
        bpr_marginal_time(out.loc[i, "t0"], out.loc[i, "flow"],
                          out.loc[i, "cap"], out.loc[i, "alpha"], out.loc[i, "beta"])
        for i in range(len(out))
    ]

    return out


# ----------------------------
# 5) main
# ----------------------------
if __name__ == "__main__":
    net = read_net_csv("/Users/keito-shiraki/traffic_assignment/data/csv/SiouxFalls_net_Vff60_with_minutes.csv")
    od = read_od_csv("/Users/keito-shiraki/traffic_assignment/data/csv/SiouxFalls_od.csv")

    result = run_logit_sue_so_congestion_co2(
        net=net,
        od=od,
        k_paths=5,
        mu=100.0,
        beta_time=1.0,
        max_iter=500,
        tol=1e-6
    )

    result.to_csv("assignment_result_SO_congestion_CO2_min2.csv", index=False)
    print("Saved: assignment_result_SO_congestion_CO2_min2.csv")
# Out:
# [SO+CO2] Iter 01 | step=1.0000 | rel_change=8.881000e+05
# [SO+CO2] Iter 02 | step=0.5000 | rel_change=8.377849e-01
# [SO+CO2] Iter 03 | step=0.3333 | rel_change=4.164270e-01
# [SO+CO2] Iter 04 | step=0.2500 | rel_change=2.184624e-01
# [SO+CO2] Iter 05 | step=0.2000 | rel_change=1.486770e-01
# [SO+CO2] Iter 06 | step=0.1667 | rel_change=9.775184e-02
# [SO+CO2] Iter 07 | step=0.1429 | rel_change=6.300168e-02
# [SO+CO2] Iter 08 | step=0.1250 | rel_change=4.553057e-02
# [SO+CO2] Iter 09 | step=0.1111 | rel_change=3.817381e-02
# [SO+CO2] Iter 10 | step=0.1000 | rel_change=2.580327e-02
# [SO+CO2] Iter 11 | step=0.0909 | rel_change=2.479369e-02
# [SO+CO2] Iter 12 | step=0.0833 | rel_change=2.358095e-02
# [SO+CO2] Iter 13 | step=0.0769 | rel_change=2.581362e-02
# [SO+CO2] Iter 14 | step=0.0714 | rel_change=1.971033e-02
# [SO+CO2] Iter 15 | step=0.0667 | rel_change=1.751487e-02
# [SO+CO2] Iter 16 | step=0.0625 | rel_change=1.439412e-02
# [SO+CO2] Iter 17 | step=0.0588 | rel_change=1.626018e-02
# [SO+CO2] Iter 18 | step=0.0556 | rel_change=1.210624e-02
# [SO+CO2] Iter 19 | step=0.0526 | rel_change=1.229504e-02
# [SO+CO2] Iter 20 | step=0.0500 | rel_change=9.729904e-03
# [SO+CO2] Iter 21 | step=0.0476 | rel_change=9.400333e-03
# [SO+CO2] Iter 22 | step=0.0455 | rel_change=1.125472e-02
# [SO+CO2] Iter 23 | step=0.0435 | rel_change=1.234752e-02
# [SO+CO2] Iter 24 | step=0.0417 | rel_change=8.263281e-03
# [SO+CO2] Iter 25 | step=0.0400 | rel_change=8.938454e-03
# [SO+CO2] Iter 26 | step=0.0385 | rel_change=8.781599e-03
# [SO+CO2] Iter 27 | step=0.0370 | rel_change=8.746203e-03
# [SO+CO2] Iter 28 | step=0.0357 | rel_change=8.339919e-03
# [SO+CO2] Iter 29 | step=0.0345 | rel_change=8.525001e-03
# [SO+CO2] Iter 30 | step=0.0333 | rel_change=7.381899e-03
# [SO+CO2] Iter 31 | step=0.0323 | rel_change=7.268679e-03
# [SO+CO2] Iter 32 | step=0.0312 | rel_change=6.305031e-03
# [SO+CO2] Iter 33 | step=0.0303 | rel_change=6.955176e-03
# [SO+CO2] Iter 34 | step=0.0294 | rel_change=7.098849e-03
# [SO+CO2] Iter 35 | step=0.0286 | rel_change=7.375565e-03
# [SO+CO2] Iter 36 | step=0.0278 | rel_change=5.650056e-03
# [SO+CO2] Iter 37 | step=0.0270 | rel_change=5.688112e-03
# [SO+CO2] Iter 38 | step=0.0263 | rel_change=6.703730e-03
# [SO+CO2] Iter 39 | step=0.0256 | rel_change=5.472779e-03
# [SO+CO2] Iter 40 | step=0.0250 | rel_change=4.092922e-03
# [SO+CO2] Iter 41 | step=0.0244 | rel_change=4.575653e-03
# [SO+CO2] Iter 42 | step=0.0238 | rel_change=5.473589e-03
# [SO+CO2] Iter 43 | step=0.0233 | rel_change=5.385564e-03
# [SO+CO2] Iter 44 | step=0.0227 | rel_change=4.723266e-03
# [SO+CO2] Iter 45 | step=0.0222 | rel_change=4.269564e-03
# [SO+CO2] Iter 46 | step=0.0217 | rel_change=4.142256e-03
# [SO+CO2] Iter 47 | step=0.0213 | rel_change=5.046840e-03
# [SO+CO2] Iter 48 | step=0.0208 | rel_change=4.467514e-03
# [SO+CO2] Iter 49 | step=0.0204 | rel_change=4.377407e-03
# [SO+CO2] Iter 50 | step=0.0200 | rel_change=3.994279e-03
# [SO+CO2] Iter 51 | step=0.0196 | rel_change=4.197516e-03
# [SO+CO2] Iter 52 | step=0.0192 | rel_change=3.815077e-03
# [SO+CO2] Iter 53 | step=0.0189 | rel_change=3.550204e-03
# [SO+CO2] Iter 54 | step=0.0185 | rel_change=3.815153e-03
# [SO+CO2] Iter 55 | step=0.0182 | rel_change=4.177981e-03
# [SO+CO2] Iter 56 | step=0.0179 | rel_change=3.907737e-03
# [SO+CO2] Iter 57 | step=0.0175 | rel_change=3.784475e-03
# [SO+CO2] Iter 58 | step=0.0172 | rel_change=3.616598e-03
# [SO+CO2] Iter 59 | step=0.0169 | rel_change=3.136759e-03
# [SO+CO2] Iter 60 | step=0.0167 | rel_change=3.730442e-03
# [SO+CO2] Iter 61 | step=0.0164 | rel_change=4.098918e-03
# [SO+CO2] Iter 62 | step=0.0161 | rel_change=3.555284e-03
# [SO+CO2] Iter 63 | step=0.0159 | rel_change=3.064050e-03
# [SO+CO2] Iter 64 | step=0.0156 | rel_change=2.564154e-03
# [SO+CO2] Iter 65 | step=0.0154 | rel_change=3.229635e-03
# [SO+CO2] Iter 66 | step=0.0152 | rel_change=2.724920e-03
# [SO+CO2] Iter 67 | step=0.0149 | rel_change=2.811814e-03
# [SO+CO2] Iter 68 | step=0.0147 | rel_change=2.949808e-03
# [SO+CO2] Iter 69 | step=0.0145 | rel_change=3.927242e-03
# [SO+CO2] Iter 70 | step=0.0143 | rel_change=3.349403e-03
# [SO+CO2] Iter 71 | step=0.0141 | rel_change=2.942783e-03
# [SO+CO2] Iter 72 | step=0.0139 | rel_change=2.564209e-03
# [SO+CO2] Iter 73 | step=0.0137 | rel_change=2.309080e-03
# [SO+CO2] Iter 74 | step=0.0135 | rel_change=3.273984e-03
# [SO+CO2] Iter 75 | step=0.0133 | rel_change=3.146386e-03
# [SO+CO2] Iter 76 | step=0.0132 | rel_change=2.272952e-03
# [SO+CO2] Iter 77 | step=0.0130 | rel_change=2.575957e-03
# [SO+CO2] Iter 78 | step=0.0128 | rel_change=2.446071e-03
# [SO+CO2] Iter 79 | step=0.0127 | rel_change=2.991454e-03
# [SO+CO2] Iter 80 | step=0.0125 | rel_change=2.963113e-03
# [SO+CO2] Iter 81 | step=0.0123 | rel_change=2.585901e-03
# [SO+CO2] Iter 82 | step=0.0122 | rel_change=2.542963e-03
# [SO+CO2] Iter 83 | step=0.0120 | rel_change=2.018569e-03
# [SO+CO2] Iter 84 | step=0.0119 | rel_change=2.499551e-03
# [SO+CO2] Iter 85 | step=0.0118 | rel_change=3.004381e-03
# [SO+CO2] Iter 86 | step=0.0116 | rel_change=2.899693e-03
# [SO+CO2] Iter 87 | step=0.0115 | rel_change=2.140814e-03
# [SO+CO2] Iter 88 | step=0.0114 | rel_change=2.245544e-03
# [SO+CO2] Iter 89 | step=0.0112 | rel_change=2.374885e-03
# [SO+CO2] Iter 90 | step=0.0111 | rel_change=2.166111e-03
# [SO+CO2] Iter 91 | step=0.0110 | rel_change=2.204893e-03
# [SO+CO2] Iter 92 | step=0.0109 | rel_change=2.488942e-03
# [SO+CO2] Iter 93 | step=0.0108 | rel_change=2.392910e-03
# [SO+CO2] Iter 94 | step=0.0106 | rel_change=2.117607e-03
# [SO+CO2] Iter 95 | step=0.0105 | rel_change=2.020908e-03
# [SO+CO2] Iter 96 | step=0.0104 | rel_change=2.017706e-03
# [SO+CO2] Iter 97 | step=0.0103 | rel_change=2.025801e-03
# [SO+CO2] Iter 98 | step=0.0102 | rel_change=2.638139e-03
# [SO+CO2] Iter 99 | step=0.0101 | rel_change=2.108013e-03
# [SO+CO2] Iter 100 | step=0.0100 | rel_change=2.152103e-03
# [SO+CO2] Iter 101 | step=0.0099 | rel_change=2.213802e-03
# [SO+CO2] Iter 102 | step=0.0098 | rel_change=2.162128e-03
# [SO+CO2] Iter 103 | step=0.0097 | rel_change=1.924807e-03
# [SO+CO2] Iter 104 | step=0.0096 | rel_change=2.119235e-03
# [SO+CO2] Iter 105 | step=0.0095 | rel_change=1.952672e-03
# [SO+CO2] Iter 106 | step=0.0094 | rel_change=2.302358e-03
# [SO+CO2] Iter 107 | step=0.0093 | rel_change=1.869456e-03
# [SO+CO2] Iter 108 | step=0.0093 | rel_change=1.540196e-03
# [SO+CO2] Iter 109 | step=0.0092 | rel_change=1.577986e-03
# [SO+CO2] Iter 110 | step=0.0091 | rel_change=2.253484e-03
# [SO+CO2] Iter 111 | step=0.0090 | rel_change=2.234110e-03
# [SO+CO2] Iter 112 | step=0.0089 | rel_change=1.863987e-03
# [SO+CO2] Iter 113 | step=0.0088 | rel_change=1.330687e-03
# [SO+CO2] Iter 114 | step=0.0088 | rel_change=1.755252e-03
# [SO+CO2] Iter 115 | step=0.0087 | rel_change=1.661453e-03
# [SO+CO2] Iter 116 | step=0.0086 | rel_change=1.928928e-03
# [SO+CO2] Iter 117 | step=0.0085 | rel_change=1.581739e-03
# [SO+CO2] Iter 118 | step=0.0085 | rel_change=1.704614e-03
# [SO+CO2] Iter 119 | step=0.0084 | rel_change=1.816951e-03
# [SO+CO2] Iter 120 | step=0.0083 | rel_change=1.464111e-03
# [SO+CO2] Iter 121 | step=0.0083 | rel_change=1.674428e-03
# [SO+CO2] Iter 122 | step=0.0082 | rel_change=2.000744e-03
# [SO+CO2] Iter 123 | step=0.0081 | rel_change=1.761052e-03
# [SO+CO2] Iter 124 | step=0.0081 | rel_change=1.296720e-03
# [SO+CO2] Iter 125 | step=0.0080 | rel_change=1.590184e-03
# [SO+CO2] Iter 126 | step=0.0079 | rel_change=1.879314e-03
# [SO+CO2] Iter 127 | step=0.0079 | rel_change=1.654769e-03
# [SO+CO2] Iter 128 | step=0.0078 | rel_change=1.672929e-03
# [SO+CO2] Iter 129 | step=0.0078 | rel_change=2.067064e-03
# [SO+CO2] Iter 130 | step=0.0077 | rel_change=1.509465e-03
# [SO+CO2] Iter 131 | step=0.0076 | rel_change=1.322304e-03
# [SO+CO2] Iter 132 | step=0.0076 | rel_change=1.229399e-03
# [SO+CO2] Iter 133 | step=0.0075 | rel_change=1.065636e-03
# [SO+CO2] Iter 134 | step=0.0075 | rel_change=1.737611e-03
# [SO+CO2] Iter 135 | step=0.0074 | rel_change=1.777749e-03
# [SO+CO2] Iter 136 | step=0.0074 | rel_change=1.585657e-03
# [SO+CO2] Iter 137 | step=0.0073 | rel_change=1.207579e-03
# [SO+CO2] Iter 138 | step=0.0072 | rel_change=1.585711e-03
# [SO+CO2] Iter 139 | step=0.0072 | rel_change=1.619159e-03
# [SO+CO2] Iter 140 | step=0.0071 | rel_change=1.155254e-03
# [SO+CO2] Iter 141 | step=0.0071 | rel_change=1.342624e-03
# [SO+CO2] Iter 142 | step=0.0070 | rel_change=1.914072e-03
# [SO+CO2] Iter 143 | step=0.0070 | rel_change=1.526591e-03
# [SO+CO2] Iter 144 | step=0.0069 | rel_change=1.331799e-03
# [SO+CO2] Iter 145 | step=0.0069 | rel_change=1.353224e-03
# [SO+CO2] Iter 146 | step=0.0068 | rel_change=1.673733e-03
# [SO+CO2] Iter 147 | step=0.0068 | rel_change=1.674271e-03
# [SO+CO2] Iter 148 | step=0.0068 | rel_change=1.380796e-03
# [SO+CO2] Iter 149 | step=0.0067 | rel_change=1.143223e-03
# [SO+CO2] Iter 150 | step=0.0067 | rel_change=1.593068e-03
# [SO+CO2] Iter 151 | step=0.0066 | rel_change=1.539891e-03
# [SO+CO2] Iter 152 | step=0.0066 | rel_change=1.345522e-03
# [SO+CO2] Iter 153 | step=0.0065 | rel_change=1.151853e-03
# [SO+CO2] Iter 154 | step=0.0065 | rel_change=1.255778e-03
# [SO+CO2] Iter 155 | step=0.0065 | rel_change=1.422760e-03
# [SO+CO2] Iter 156 | step=0.0064 | rel_change=1.354596e-03
# [SO+CO2] Iter 157 | step=0.0064 | rel_change=1.290486e-03
# [SO+CO2] Iter 158 | step=0.0063 | rel_change=1.381530e-03
# [SO+CO2] Iter 159 | step=0.0063 | rel_change=1.285076e-03
# [SO+CO2] Iter 160 | step=0.0063 | rel_change=1.128193e-03
# [SO+CO2] Iter 161 | step=0.0062 | rel_change=9.839409e-04
# [SO+CO2] Iter 162 | step=0.0062 | rel_change=1.315999e-03
# [SO+CO2] Iter 163 | step=0.0061 | rel_change=1.191350e-03
# [SO+CO2] Iter 164 | step=0.0061 | rel_change=9.204127e-04
# [SO+CO2] Iter 165 | step=0.0061 | rel_change=1.333716e-03
# [SO+CO2] Iter 166 | step=0.0060 | rel_change=1.317420e-03
# [SO+CO2] Iter 167 | step=0.0060 | rel_change=1.060669e-03
# [SO+CO2] Iter 168 | step=0.0060 | rel_change=1.230119e-03
# [SO+CO2] Iter 169 | step=0.0059 | rel_change=1.183009e-03
# [SO+CO2] Iter 170 | step=0.0059 | rel_change=1.257737e-03
# [SO+CO2] Iter 171 | step=0.0058 | rel_change=1.330630e-03
# [SO+CO2] Iter 172 | step=0.0058 | rel_change=1.300276e-03
# [SO+CO2] Iter 173 | step=0.0058 | rel_change=1.043458e-03
# [SO+CO2] Iter 174 | step=0.0057 | rel_change=9.873462e-04
# [SO+CO2] Iter 175 | step=0.0057 | rel_change=1.125103e-03
# [SO+CO2] Iter 176 | step=0.0057 | rel_change=9.517599e-04
# [SO+CO2] Iter 177 | step=0.0056 | rel_change=1.205846e-03
# [SO+CO2] Iter 178 | step=0.0056 | rel_change=1.060572e-03
# [SO+CO2] Iter 179 | step=0.0056 | rel_change=1.178716e-03
# [SO+CO2] Iter 180 | step=0.0056 | rel_change=1.080114e-03
# [SO+CO2] Iter 181 | step=0.0055 | rel_change=9.876876e-04
# [SO+CO2] Iter 182 | step=0.0055 | rel_change=8.425520e-04
# [SO+CO2] Iter 183 | step=0.0055 | rel_change=1.210336e-03
# [SO+CO2] Iter 184 | step=0.0054 | rel_change=1.248142e-03
# [SO+CO2] Iter 185 | step=0.0054 | rel_change=1.029420e-03
# [SO+CO2] Iter 186 | step=0.0054 | rel_change=9.884526e-04
# [SO+CO2] Iter 187 | step=0.0053 | rel_change=1.071062e-03
# [SO+CO2] Iter 188 | step=0.0053 | rel_change=1.110618e-03
# [SO+CO2] Iter 189 | step=0.0053 | rel_change=1.250465e-03
# [SO+CO2] Iter 190 | step=0.0053 | rel_change=9.573694e-04
# [SO+CO2] Iter 191 | step=0.0052 | rel_change=1.146094e-03
# [SO+CO2] Iter 192 | step=0.0052 | rel_change=1.209653e-03
# [SO+CO2] Iter 193 | step=0.0052 | rel_change=1.037103e-03
# [SO+CO2] Iter 194 | step=0.0052 | rel_change=8.542862e-04
# [SO+CO2] Iter 195 | step=0.0051 | rel_change=1.207225e-03
# [SO+CO2] Iter 196 | step=0.0051 | rel_change=8.524147e-04
# [SO+CO2] Iter 197 | step=0.0051 | rel_change=1.057238e-03
# [SO+CO2] Iter 198 | step=0.0051 | rel_change=9.332133e-04
# [SO+CO2] Iter 199 | step=0.0050 | rel_change=7.952264e-04
# [SO+CO2] Iter 200 | step=0.0050 | rel_change=1.042170e-03
# [SO+CO2] Iter 201 | step=0.0050 | rel_change=1.235051e-03
# [SO+CO2] Iter 202 | step=0.0050 | rel_change=7.849969e-04
# [SO+CO2] Iter 203 | step=0.0049 | rel_change=8.663684e-04
# [SO+CO2] Iter 204 | step=0.0049 | rel_change=9.083581e-04
# [SO+CO2] Iter 205 | step=0.0049 | rel_change=1.105302e-03
# [SO+CO2] Iter 206 | step=0.0049 | rel_change=9.236014e-04
# [SO+CO2] Iter 207 | step=0.0048 | rel_change=9.376954e-04
# [SO+CO2] Iter 208 | step=0.0048 | rel_change=8.251631e-04
# [SO+CO2] Iter 209 | step=0.0048 | rel_change=9.574107e-04
# [SO+CO2] Iter 210 | step=0.0048 | rel_change=9.329842e-04
# [SO+CO2] Iter 211 | step=0.0047 | rel_change=1.045371e-03
# [SO+CO2] Iter 212 | step=0.0047 | rel_change=9.605937e-04
# [SO+CO2] Iter 213 | step=0.0047 | rel_change=1.110435e-03
# [SO+CO2] Iter 214 | step=0.0047 | rel_change=1.027548e-03
# [SO+CO2] Iter 215 | step=0.0047 | rel_change=9.296697e-04
# [SO+CO2] Iter 216 | step=0.0046 | rel_change=8.880389e-04
# [SO+CO2] Iter 217 | step=0.0046 | rel_change=7.834674e-04
# [SO+CO2] Iter 218 | step=0.0046 | rel_change=8.239445e-04
# [SO+CO2] Iter 219 | step=0.0046 | rel_change=1.222890e-03
# [SO+CO2] Iter 220 | step=0.0045 | rel_change=8.861639e-04
# [SO+CO2] Iter 221 | step=0.0045 | rel_change=7.148993e-04
# [SO+CO2] Iter 222 | step=0.0045 | rel_change=7.964644e-04
# [SO+CO2] Iter 223 | step=0.0045 | rel_change=1.156211e-03
# [SO+CO2] Iter 224 | step=0.0045 | rel_change=8.866786e-04
# [SO+CO2] Iter 225 | step=0.0044 | rel_change=8.665227e-04
# [SO+CO2] Iter 226 | step=0.0044 | rel_change=9.162912e-04
# [SO+CO2] Iter 227 | step=0.0044 | rel_change=7.320276e-04
# [SO+CO2] Iter 228 | step=0.0044 | rel_change=7.642371e-04
# [SO+CO2] Iter 229 | step=0.0044 | rel_change=1.041042e-03
# [SO+CO2] Iter 230 | step=0.0043 | rel_change=9.244049e-04
# [SO+CO2] Iter 231 | step=0.0043 | rel_change=7.781365e-04
# [SO+CO2] Iter 232 | step=0.0043 | rel_change=8.676973e-04
# [SO+CO2] Iter 233 | step=0.0043 | rel_change=7.938869e-04
# [SO+CO2] Iter 234 | step=0.0043 | rel_change=8.550318e-04
# [SO+CO2] Iter 235 | step=0.0043 | rel_change=9.216262e-04
# [SO+CO2] Iter 236 | step=0.0042 | rel_change=1.015064e-03
# [SO+CO2] Iter 237 | step=0.0042 | rel_change=8.150899e-04
# [SO+CO2] Iter 238 | step=0.0042 | rel_change=6.536121e-04
# [SO+CO2] Iter 239 | step=0.0042 | rel_change=6.058697e-04
# [SO+CO2] Iter 240 | step=0.0042 | rel_change=9.268495e-04
# [SO+CO2] Iter 241 | step=0.0041 | rel_change=7.763286e-04
# [SO+CO2] Iter 242 | step=0.0041 | rel_change=7.581145e-04
# [SO+CO2] Iter 243 | step=0.0041 | rel_change=7.094291e-04
# [SO+CO2] Iter 244 | step=0.0041 | rel_change=8.501269e-04
# [SO+CO2] Iter 245 | step=0.0041 | rel_change=7.746834e-04
# [SO+CO2] Iter 246 | step=0.0041 | rel_change=9.379182e-04
# [SO+CO2] Iter 247 | step=0.0040 | rel_change=9.209724e-04
# [SO+CO2] Iter 248 | step=0.0040 | rel_change=6.868189e-04
# [SO+CO2] Iter 249 | step=0.0040 | rel_change=8.474192e-04
# [SO+CO2] Iter 250 | step=0.0040 | rel_change=8.946584e-04
# [SO+CO2] Iter 251 | step=0.0040 | rel_change=6.932001e-04
# [SO+CO2] Iter 252 | step=0.0040 | rel_change=8.225454e-04
# [SO+CO2] Iter 253 | step=0.0040 | rel_change=9.333633e-04
# [SO+CO2] Iter 254 | step=0.0039 | rel_change=7.900898e-04
# [SO+CO2] Iter 255 | step=0.0039 | rel_change=5.807796e-04
# [SO+CO2] Iter 256 | step=0.0039 | rel_change=7.240643e-04
# [SO+CO2] Iter 257 | step=0.0039 | rel_change=7.267859e-04
# [SO+CO2] Iter 258 | step=0.0039 | rel_change=7.317967e-04
# [SO+CO2] Iter 259 | step=0.0039 | rel_change=7.348811e-04
# [SO+CO2] Iter 260 | step=0.0038 | rel_change=8.023072e-04
# [SO+CO2] Iter 261 | step=0.0038 | rel_change=8.491991e-04
# [SO+CO2] Iter 262 | step=0.0038 | rel_change=8.087251e-04
# [SO+CO2] Iter 263 | step=0.0038 | rel_change=6.743798e-04
# [SO+CO2] Iter 264 | step=0.0038 | rel_change=7.735779e-04
# [SO+CO2] Iter 265 | step=0.0038 | rel_change=7.711657e-04
# [SO+CO2] Iter 266 | step=0.0038 | rel_change=7.416168e-04
# [SO+CO2] Iter 267 | step=0.0037 | rel_change=8.202272e-04
# [SO+CO2] Iter 268 | step=0.0037 | rel_change=7.766039e-04
# [SO+CO2] Iter 269 | step=0.0037 | rel_change=7.891367e-04
# [SO+CO2] Iter 270 | step=0.0037 | rel_change=7.332451e-04
# [SO+CO2] Iter 271 | step=0.0037 | rel_change=6.559221e-04
# [SO+CO2] Iter 272 | step=0.0037 | rel_change=8.717824e-04
# [SO+CO2] Iter 273 | step=0.0037 | rel_change=7.271019e-04
# [SO+CO2] Iter 274 | step=0.0036 | rel_change=7.139721e-04
# [SO+CO2] Iter 275 | step=0.0036 | rel_change=8.017042e-04
# [SO+CO2] Iter 276 | step=0.0036 | rel_change=7.207703e-04
# [SO+CO2] Iter 277 | step=0.0036 | rel_change=7.451899e-04
# [SO+CO2] Iter 278 | step=0.0036 | rel_change=6.832794e-04
# [SO+CO2] Iter 279 | step=0.0036 | rel_change=6.539885e-04
# [SO+CO2] Iter 280 | step=0.0036 | rel_change=6.705893e-04
# [SO+CO2] Iter 281 | step=0.0036 | rel_change=6.524694e-04
# [SO+CO2] Iter 282 | step=0.0035 | rel_change=6.731680e-04
# [SO+CO2] Iter 283 | step=0.0035 | rel_change=7.665785e-04
# [SO+CO2] Iter 284 | step=0.0035 | rel_change=8.288218e-04
# [SO+CO2] Iter 285 | step=0.0035 | rel_change=6.793242e-04
# [SO+CO2] Iter 286 | step=0.0035 | rel_change=6.817894e-04
# [SO+CO2] Iter 287 | step=0.0035 | rel_change=7.066754e-04
# [SO+CO2] Iter 288 | step=0.0035 | rel_change=5.437822e-04
# [SO+CO2] Iter 289 | step=0.0035 | rel_change=6.846003e-04
# [SO+CO2] Iter 290 | step=0.0034 | rel_change=7.029321e-04
# [SO+CO2] Iter 291 | step=0.0034 | rel_change=6.686643e-04
# [SO+CO2] Iter 292 | step=0.0034 | rel_change=7.483385e-04
# [SO+CO2] Iter 293 | step=0.0034 | rel_change=6.546477e-04
# [SO+CO2] Iter 294 | step=0.0034 | rel_change=6.670227e-04
# [SO+CO2] Iter 295 | step=0.0034 | rel_change=6.408153e-04
# [SO+CO2] Iter 296 | step=0.0034 | rel_change=6.535763e-04
# [SO+CO2] Iter 297 | step=0.0034 | rel_change=6.132424e-04
# [SO+CO2] Iter 298 | step=0.0034 | rel_change=6.484232e-04
# [SO+CO2] Iter 299 | step=0.0033 | rel_change=5.968919e-04
# [SO+CO2] Iter 300 | step=0.0033 | rel_change=5.350433e-04
# [SO+CO2] Iter 301 | step=0.0033 | rel_change=6.889755e-04
# [SO+CO2] Iter 302 | step=0.0033 | rel_change=7.523492e-04
# [SO+CO2] Iter 303 | step=0.0033 | rel_change=7.474281e-04
# [SO+CO2] Iter 304 | step=0.0033 | rel_change=5.429418e-04
# [SO+CO2] Iter 305 | step=0.0033 | rel_change=5.676717e-04
# [SO+CO2] Iter 306 | step=0.0033 | rel_change=5.561013e-04
# [SO+CO2] Iter 307 | step=0.0033 | rel_change=6.326583e-04
# [SO+CO2] Iter 308 | step=0.0032 | rel_change=6.129976e-04
# [SO+CO2] Iter 309 | step=0.0032 | rel_change=6.535741e-04
# [SO+CO2] Iter 310 | step=0.0032 | rel_change=7.209899e-04
# [SO+CO2] Iter 311 | step=0.0032 | rel_change=6.680468e-04
# [SO+CO2] Iter 312 | step=0.0032 | rel_change=6.083735e-04
# [SO+CO2] Iter 313 | step=0.0032 | rel_change=5.148344e-04
# [SO+CO2] Iter 314 | step=0.0032 | rel_change=7.171937e-04
# [SO+CO2] Iter 315 | step=0.0032 | rel_change=5.907993e-04
# [SO+CO2] Iter 316 | step=0.0032 | rel_change=5.848260e-04
# [SO+CO2] Iter 317 | step=0.0032 | rel_change=5.725137e-04
# [SO+CO2] Iter 318 | step=0.0031 | rel_change=6.119921e-04
# [SO+CO2] Iter 319 | step=0.0031 | rel_change=5.354790e-04
# [SO+CO2] Iter 320 | step=0.0031 | rel_change=5.539119e-04
# [SO+CO2] Iter 321 | step=0.0031 | rel_change=4.500589e-04
# [SO+CO2] Iter 322 | step=0.0031 | rel_change=5.577148e-04
# [SO+CO2] Iter 323 | step=0.0031 | rel_change=7.502048e-04
# [SO+CO2] Iter 324 | step=0.0031 | rel_change=6.862067e-04
# [SO+CO2] Iter 325 | step=0.0031 | rel_change=4.863903e-04
# [SO+CO2] Iter 326 | step=0.0031 | rel_change=6.309553e-04
# [SO+CO2] Iter 327 | step=0.0031 | rel_change=5.579189e-04
# [SO+CO2] Iter 328 | step=0.0030 | rel_change=4.356139e-04
# [SO+CO2] Iter 329 | step=0.0030 | rel_change=3.989934e-04
# [SO+CO2] Iter 330 | step=0.0030 | rel_change=6.872212e-04
# [SO+CO2] Iter 331 | step=0.0030 | rel_change=7.709451e-04
# [SO+CO2] Iter 332 | step=0.0030 | rel_change=6.528129e-04
# [SO+CO2] Iter 333 | step=0.0030 | rel_change=4.720482e-04
# [SO+CO2] Iter 334 | step=0.0030 | rel_change=4.661979e-04
# [SO+CO2] Iter 335 | step=0.0030 | rel_change=6.724116e-04
# [SO+CO2] Iter 336 | step=0.0030 | rel_change=7.051568e-04
# [SO+CO2] Iter 337 | step=0.0030 | rel_change=5.309647e-04
# [SO+CO2] Iter 338 | step=0.0030 | rel_change=4.582155e-04
# [SO+CO2] Iter 339 | step=0.0029 | rel_change=5.069092e-04
# [SO+CO2] Iter 340 | step=0.0029 | rel_change=4.606976e-04
# [SO+CO2] Iter 341 | step=0.0029 | rel_change=5.710631e-04
# [SO+CO2] Iter 342 | step=0.0029 | rel_change=7.477721e-04
# [SO+CO2] Iter 343 | step=0.0029 | rel_change=5.275930e-04
# [SO+CO2] Iter 344 | step=0.0029 | rel_change=4.142264e-04
# [SO+CO2] Iter 345 | step=0.0029 | rel_change=5.874916e-04
# [SO+CO2] Iter 346 | step=0.0029 | rel_change=6.026318e-04
# [SO+CO2] Iter 347 | step=0.0029 | rel_change=5.600190e-04
# [SO+CO2] Iter 348 | step=0.0029 | rel_change=5.043171e-04
# [SO+CO2] Iter 349 | step=0.0029 | rel_change=5.288505e-04
# [SO+CO2] Iter 350 | step=0.0029 | rel_change=5.058296e-04
# [SO+CO2] Iter 351 | step=0.0028 | rel_change=4.966925e-04
# [SO+CO2] Iter 352 | step=0.0028 | rel_change=6.333174e-04
# [SO+CO2] Iter 353 | step=0.0028 | rel_change=6.505963e-04
# [SO+CO2] Iter 354 | step=0.0028 | rel_change=5.284850e-04
# [SO+CO2] Iter 355 | step=0.0028 | rel_change=4.470298e-04
# [SO+CO2] Iter 356 | step=0.0028 | rel_change=5.157088e-04
# [SO+CO2] Iter 357 | step=0.0028 | rel_change=4.792416e-04
# [SO+CO2] Iter 358 | step=0.0028 | rel_change=4.261908e-04
# [SO+CO2] Iter 359 | step=0.0028 | rel_change=4.747247e-04
# [SO+CO2] Iter 360 | step=0.0028 | rel_change=5.738638e-04
# [SO+CO2] Iter 361 | step=0.0028 | rel_change=4.939478e-04
# [SO+CO2] Iter 362 | step=0.0028 | rel_change=5.873597e-04
# [SO+CO2] Iter 363 | step=0.0028 | rel_change=6.300066e-04
# [SO+CO2] Iter 364 | step=0.0027 | rel_change=6.013626e-04
# [SO+CO2] Iter 365 | step=0.0027 | rel_change=4.792611e-04
# [SO+CO2] Iter 366 | step=0.0027 | rel_change=4.534052e-04
# [SO+CO2] Iter 367 | step=0.0027 | rel_change=4.747550e-04
# [SO+CO2] Iter 368 | step=0.0027 | rel_change=5.295658e-04
# [SO+CO2] Iter 369 | step=0.0027 | rel_change=5.401748e-04
# [SO+CO2] Iter 370 | step=0.0027 | rel_change=4.574544e-04
# [SO+CO2] Iter 371 | step=0.0027 | rel_change=4.315390e-04
# [SO+CO2] Iter 372 | step=0.0027 | rel_change=3.712657e-04
# [SO+CO2] Iter 373 | step=0.0027 | rel_change=5.092938e-04
# [SO+CO2] Iter 374 | step=0.0027 | rel_change=6.394983e-04
# [SO+CO2] Iter 375 | step=0.0027 | rel_change=6.044398e-04
# [SO+CO2] Iter 376 | step=0.0027 | rel_change=4.323737e-04
# [SO+CO2] Iter 377 | step=0.0027 | rel_change=4.285238e-04
# [SO+CO2] Iter 378 | step=0.0026 | rel_change=4.287043e-04
# [SO+CO2] Iter 379 | step=0.0026 | rel_change=5.385332e-04
# [SO+CO2] Iter 380 | step=0.0026 | rel_change=6.342597e-04
# [SO+CO2] Iter 381 | step=0.0026 | rel_change=4.945847e-04
# [SO+CO2] Iter 382 | step=0.0026 | rel_change=3.807608e-04
# [SO+CO2] Iter 383 | step=0.0026 | rel_change=4.940406e-04
# [SO+CO2] Iter 384 | step=0.0026 | rel_change=5.820243e-04
# [SO+CO2] Iter 385 | step=0.0026 | rel_change=4.723987e-04
# [SO+CO2] Iter 386 | step=0.0026 | rel_change=4.707603e-04
# [SO+CO2] Iter 387 | step=0.0026 | rel_change=5.664616e-04
# [SO+CO2] Iter 388 | step=0.0026 | rel_change=4.620678e-04
# [SO+CO2] Iter 389 | step=0.0026 | rel_change=4.284497e-04
# [SO+CO2] Iter 390 | step=0.0026 | rel_change=5.021656e-04
# [SO+CO2] Iter 391 | step=0.0026 | rel_change=5.304516e-04
# [SO+CO2] Iter 392 | step=0.0026 | rel_change=4.732196e-04
# [SO+CO2] Iter 393 | step=0.0025 | rel_change=4.608645e-04
# [SO+CO2] Iter 394 | step=0.0025 | rel_change=4.796768e-04
# [SO+CO2] Iter 395 | step=0.0025 | rel_change=5.821652e-04
# [SO+CO2] Iter 396 | step=0.0025 | rel_change=4.873301e-04
# [SO+CO2] Iter 397 | step=0.0025 | rel_change=4.288002e-04
# [SO+CO2] Iter 398 | step=0.0025 | rel_change=4.122994e-04
# [SO+CO2] Iter 399 | step=0.0025 | rel_change=4.310337e-04
# [SO+CO2] Iter 400 | step=0.0025 | rel_change=3.633670e-04
# [SO+CO2] Iter 401 | step=0.0025 | rel_change=3.752928e-04
# [SO+CO2] Iter 402 | step=0.0025 | rel_change=6.116375e-04
# [SO+CO2] Iter 403 | step=0.0025 | rel_change=5.418786e-04
# [SO+CO2] Iter 404 | step=0.0025 | rel_change=3.465784e-04
# [SO+CO2] Iter 405 | step=0.0025 | rel_change=4.382173e-04
# [SO+CO2] Iter 406 | step=0.0025 | rel_change=4.696192e-04
# [SO+CO2] Iter 407 | step=0.0025 | rel_change=4.168637e-04
# [SO+CO2] Iter 408 | step=0.0025 | rel_change=4.097392e-04
# [SO+CO2] Iter 409 | step=0.0024 | rel_change=4.061192e-04
# [SO+CO2] Iter 410 | step=0.0024 | rel_change=4.093018e-04
# [SO+CO2] Iter 411 | step=0.0024 | rel_change=5.030972e-04
# [SO+CO2] Iter 412 | step=0.0024 | rel_change=5.396656e-04
# [SO+CO2] Iter 413 | step=0.0024 | rel_change=5.381473e-04
# [SO+CO2] Iter 414 | step=0.0024 | rel_change=4.518471e-04
# [SO+CO2] Iter 415 | step=0.0024 | rel_change=4.435490e-04
# [SO+CO2] Iter 416 | step=0.0024 | rel_change=4.223583e-04
# [SO+CO2] Iter 417 | step=0.0024 | rel_change=3.842343e-04
# [SO+CO2] Iter 418 | step=0.0024 | rel_change=4.418146e-04
# [SO+CO2] Iter 419 | step=0.0024 | rel_change=5.373948e-04
# [SO+CO2] Iter 420 | step=0.0024 | rel_change=4.832572e-04
# [SO+CO2] Iter 421 | step=0.0024 | rel_change=4.595783e-04
# [SO+CO2] Iter 422 | step=0.0024 | rel_change=4.009512e-04
# [SO+CO2] Iter 423 | step=0.0024 | rel_change=3.735349e-04
# [SO+CO2] Iter 424 | step=0.0024 | rel_change=4.767734e-04
# [SO+CO2] Iter 425 | step=0.0024 | rel_change=4.211989e-04
# [SO+CO2] Iter 426 | step=0.0023 | rel_change=4.219196e-04
# [SO+CO2] Iter 427 | step=0.0023 | rel_change=4.938303e-04
# [SO+CO2] Iter 428 | step=0.0023 | rel_change=4.806407e-04
# [SO+CO2] Iter 429 | step=0.0023 | rel_change=4.038029e-04
# [SO+CO2] Iter 430 | step=0.0023 | rel_change=4.113086e-04
# [SO+CO2] Iter 431 | step=0.0023 | rel_change=4.338272e-04
# [SO+CO2] Iter 432 | step=0.0023 | rel_change=3.829829e-04
# [SO+CO2] Iter 433 | step=0.0023 | rel_change=3.533296e-04
# [SO+CO2] Iter 434 | step=0.0023 | rel_change=4.327381e-04
# [SO+CO2] Iter 435 | step=0.0023 | rel_change=4.910942e-04
# [SO+CO2] Iter 436 | step=0.0023 | rel_change=4.452746e-04
# [SO+CO2] Iter 437 | step=0.0023 | rel_change=3.029263e-04
# [SO+CO2] Iter 438 | step=0.0023 | rel_change=3.619097e-04
# [SO+CO2] Iter 439 | step=0.0023 | rel_change=5.098783e-04
# [SO+CO2] Iter 440 | step=0.0023 | rel_change=4.776936e-04
# [SO+CO2] Iter 441 | step=0.0023 | rel_change=3.138827e-04
# [SO+CO2] Iter 442 | step=0.0023 | rel_change=3.608567e-04
# [SO+CO2] Iter 443 | step=0.0023 | rel_change=3.731014e-04
# [SO+CO2] Iter 444 | step=0.0023 | rel_change=2.979472e-04
# [SO+CO2] Iter 445 | step=0.0022 | rel_change=3.942227e-04
# [SO+CO2] Iter 446 | step=0.0022 | rel_change=4.827614e-04
# [SO+CO2] Iter 447 | step=0.0022 | rel_change=3.662992e-04
# [SO+CO2] Iter 448 | step=0.0022 | rel_change=3.539649e-04
# [SO+CO2] Iter 449 | step=0.0022 | rel_change=3.996885e-04
# [SO+CO2] Iter 450 | step=0.0022 | rel_change=3.570436e-04
# [SO+CO2] Iter 451 | step=0.0022 | rel_change=3.571442e-04
# [SO+CO2] Iter 452 | step=0.0022 | rel_change=4.727285e-04
# [SO+CO2] Iter 453 | step=0.0022 | rel_change=5.035050e-04
# [SO+CO2] Iter 454 | step=0.0022 | rel_change=4.298127e-04
# [SO+CO2] Iter 455 | step=0.0022 | rel_change=3.456996e-04
# [SO+CO2] Iter 456 | step=0.0022 | rel_change=4.159266e-04
# [SO+CO2] Iter 457 | step=0.0022 | rel_change=4.546581e-04
# [SO+CO2] Iter 458 | step=0.0022 | rel_change=3.432261e-04
# [SO+CO2] Iter 459 | step=0.0022 | rel_change=3.393176e-04
# [SO+CO2] Iter 460 | step=0.0022 | rel_change=3.965027e-04
# [SO+CO2] Iter 461 | step=0.0022 | rel_change=4.379811e-04
# [SO+CO2] Iter 462 | step=0.0022 | rel_change=3.483258e-04
# [SO+CO2] Iter 463 | step=0.0022 | rel_change=3.996044e-04
# [SO+CO2] Iter 464 | step=0.0022 | rel_change=4.708788e-04
# [SO+CO2] Iter 465 | step=0.0022 | rel_change=4.790567e-04
# [SO+CO2] Iter 466 | step=0.0021 | rel_change=3.670142e-04
# [SO+CO2] Iter 467 | step=0.0021 | rel_change=3.277390e-04
# [SO+CO2] Iter 468 | step=0.0021 | rel_change=4.269286e-04
# [SO+CO2] Iter 469 | step=0.0021 | rel_change=4.158236e-04
# [SO+CO2] Iter 470 | step=0.0021 | rel_change=3.270121e-04
# [SO+CO2] Iter 471 | step=0.0021 | rel_change=3.797551e-04
# [SO+CO2] Iter 472 | step=0.0021 | rel_change=3.557792e-04
# [SO+CO2] Iter 473 | step=0.0021 | rel_change=3.093285e-04
# [SO+CO2] Iter 474 | step=0.0021 | rel_change=3.938158e-04
# [SO+CO2] Iter 475 | step=0.0021 | rel_change=4.865274e-04
# [SO+CO2] Iter 476 | step=0.0021 | rel_change=3.954875e-04
# [SO+CO2] Iter 477 | step=0.0021 | rel_change=3.043051e-04
# [SO+CO2] Iter 478 | step=0.0021 | rel_change=3.537387e-04
# [SO+CO2] Iter 479 | step=0.0021 | rel_change=3.271908e-04
# [SO+CO2] Iter 480 | step=0.0021 | rel_change=3.446024e-04
# [SO+CO2] Iter 481 | step=0.0021 | rel_change=4.160626e-04
# [SO+CO2] Iter 482 | step=0.0021 | rel_change=4.154214e-04
# [SO+CO2] Iter 483 | step=0.0021 | rel_change=3.580584e-04
# [SO+CO2] Iter 484 | step=0.0021 | rel_change=3.859879e-04
# [SO+CO2] Iter 485 | step=0.0021 | rel_change=3.309222e-04
# [SO+CO2] Iter 486 | step=0.0021 | rel_change=2.768577e-04
# [SO+CO2] Iter 487 | step=0.0021 | rel_change=3.790622e-04
# [SO+CO2] Iter 488 | step=0.0020 | rel_change=4.752863e-04
# [SO+CO2] Iter 489 | step=0.0020 | rel_change=4.313318e-04
# [SO+CO2] Iter 490 | step=0.0020 | rel_change=3.525520e-04
# [SO+CO2] Iter 491 | step=0.0020 | rel_change=3.469830e-04
# [SO+CO2] Iter 492 | step=0.0020 | rel_change=4.319645e-04
# [SO+CO2] Iter 493 | step=0.0020 | rel_change=3.958117e-04
# [SO+CO2] Iter 494 | step=0.0020 | rel_change=3.232322e-04
# [SO+CO2] Iter 495 | step=0.0020 | rel_change=3.218705e-04
# [SO+CO2] Iter 496 | step=0.0020 | rel_change=3.968364e-04
# [SO+CO2] Iter 497 | step=0.0020 | rel_change=3.590382e-04
# [SO+CO2] Iter 498 | step=0.0020 | rel_change=3.545518e-04
# [SO+CO2] Iter 499 | step=0.0020 | rel_change=4.048008e-04
# [SO+CO2] Iter 500 | step=0.0020 | rel_change=3.728494e-04
# Saved: assignment_result_SO_congestion_CO2_min2.csv
